# %% [markdown]
# For your Individual Project, using the same nyc-violations data, conduct an Exploratory Data Analysis on the dataset and
# produce a report in your Jupyter Notebook describing insights gleaned from the dataset. Please note that this EDA report
# must contain appropriate visualizations, to show trends and insights gleaned.

# %% [markdown]
# Clean data: Check for missing or duplicate values, and handle them appropriately.
#
# Summarize data: Use descriptive statistics and visualization techniques to get a general sense of the data.
#
# Use Exploratory Data Analysi(EDA): Look for patterns, relationships, and outliers in the data. This can be done using visualization techniques such as scatter plots, histograms, and box plots.
#
# Hypotheses Formulation: Based on the patterns and relationships you find in the data, formulate hypotheses about the underlying data generating process.
#
# Test hypotheses: Use statistical methods to test the hypotheses you have formulated.

# %%
import pandas as pd

import numpy as np

from matplotlib import pyplot as plt

# %%
df = pd.read_csv('data 1.csv')
# Out:
# C:\Users\Kingsley Y. Asiedu\AppData\Local\Temp\ipykernel_19564\3883447169.py:1: DtypeWarning: Columns (34,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('data 1.csv')

# %%
df.shape
# Out:
# (50113, 45)

# %%
df.describe()
# Out:
#        Summons Number  Violation Code  Street Code1  Street Code2  \
# count    5.000000e+04    50000.000000  50000.000000  50000.000000
# mean     7.017655e+09       31.944140  19683.326600  16648.178160
# std      2.258812e+09       16.088848  22499.739403  21237.655634
# min      1.254533e+09        0.000000      0.000000      0.000000
# 25%      4.708005e+09       20.000000      0.000000      0.000000
# 50%      8.729645e+09       36.000000  12720.000000  10210.000000
# 75%      8.815425e+09       38.000000  34210.000000  27050.000000
# max      8.880300e+09       99.000000  95130.000000  98100.000000
#
#        Street Code3  Vehicle Expiration Date  Violation Location  \
# count  50000.000000             5.000000e+04        32108.000000
# mean   16489.137900             2.263959e+07           55.419179
# std    21342.886145             2.874199e+07           37.929945
# min        0.000000             0.000000e+00            1.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50113 entries, 0 to 50112
# Data columns (total 45 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Summons Number                     50000 non-null  float64
#  1   Plate ID                           50000 non-null  object
#  2   Registration State                 50000 non-null  object
#  3   Plate Type                         50000 non-null  object
#  4   Issue Date                         50000 non-null  object
#  5   Violation Code                     50000 non-null  float64
#  6   Vehicle Body Type                  49855 non-null  object
#  7   Vehicle Make                       49864 non-null  object
#  8   Issuing Agency                     50000 non-null  object
#  9   Street Code1                       50000 non-null  float64
#  10  Street Code2                       50000 non-null  float64
# ...

# %%
df.head(100)
# Out:
#     Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 0     4.714702e+09  KGK6659                 NY        PAS    11-12-20
# 1     8.793685e+09  L5232HY                 TN        PAS  09/14/2020
# 2     8.864757e+09   BPMN76                 FL        PAS  11/25/2020
# 3     8.778326e+09  57387MJ                 NY        COM  08/20/2020
# 4     4.706641e+09   M81KFJ                 NJ        PAS    09-09-20
# ..             ...      ...                ...        ...         ...
# 95    8.544336e+09  590579R                 NJ        PAS    08-10-20
# 96    4.697124e+09   050LGW                 OR        PAS    07-03-20
# 97    8.797026e+09  AE22026                 AZ        PAS  07/26/2020
# 98    8.834014e+09  JNL2717                 NY        PAS  10/22/2020
# 99    8.817431e+09  612714R                 NJ        PAS    11-10-20
#
#     Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# ...

# %%
df.tail(100)
# Out:
#        Summons Number Plate ID Registration State Plate Type Issue Date  \
# 50013             NaN      NaN                NaN        NaN        NaN
# 50014             NaN      NaN                NaN        NaN        NaN
# 50015             NaN      NaN                NaN        NaN        NaN
# 50016             NaN      NaN                NaN        NaN        NaN
# 50017             NaN      NaN                NaN        NaN        NaN
# ...               ...      ...                ...        ...        ...
# 50108             NaN      NaN                NaN        NaN        NaN
# 50109             NaN      NaN                NaN        NaN        NaN
# 50110             NaN      NaN                NaN        NaN        NaN
# 50111             NaN      NaN                NaN        NaN        NaN
# 50112             NaN      NaN                NaN        NaN        NaN
#
#        Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# ...

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [Summons Number, Plate ID, Registration State, Plate Type, Issue Date, Violation Code, Vehicle Body Type, Vehicle Make, Issuing Agency, Street Code1, Street Code2, Street Code3, Vehicle Expiration Date, Violation Location, Violation Precinct, Issuer Precinct, Issuer Code, Issuer Command, Issuer Squad, Violation Time, Time First Observed, Violation County, Violation In Front Of Or Opposite, House Number, Street Name, Intersecting Street, Date First Observed, Law Section, Sub Division, Violation Legal Code, Days Parking In Effect    , From Hours In Effect, To Hours In Effect, Vehicle Color, Unregistered Vehicle?, Vehicle Year, Meter Number, Feet From Curb, Violation Post Code, Violation Description, No Standing or Stopping Violation, Hydrant Violation, Double Parking Violation, Unnamed: 43, Unnamed: 44]
# Index: []
#
# [0 rows x 45 columns]

# %%
df.shape
# Out:
# (50113, 45)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50113 entries, 0 to 50112
# Data columns (total 45 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Summons Number                     50000 non-null  float64
#  1   Plate ID                           50000 non-null  object
#  2   Registration State                 50000 non-null  object
#  3   Plate Type                         50000 non-null  object
#  4   Issue Date                         50000 non-null  object
#  5   Violation Code                     50000 non-null  float64
#  6   Vehicle Body Type                  49855 non-null  object
#  7   Vehicle Make                       49864 non-null  object
#  8   Issuing Agency                     50000 non-null  object
#  9   Street Code1                       50000 non-null  float64
#  10  Street Code2                       50000 non-null  float64
# ...
